# %%
import pandas as pd

# %%
# extracting selected rows from a large datasets
pd.read_csv('datasets/train.csv', nrows = 500)
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 495           1066     0          1.6         0   5       0          39
# 496           1554     1          0.5         1  11       0           5
# 497           1337     0          0.5         0  13       0          31
# 498           1926     1          1.7         1   1       1          33
# 499            869     0          1.3         1   3       0          34
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.read_csv('datasets/train.csv', nrows = 200)
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# ..             ...   ...          ...       ...  ..     ...         ...
# 195           1526     0          2.1         0   1       1          23
# 196           1989     0          2.5         1   0       1          41
# 197           1308     0          1.9         0   0       1          61
# 198            609     0          0.5         0   3       0          26
# 199           1905     0          0.6         1   9       1          36
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
pd.read_csv('datasets/train.csv', nrows = 50)
# Out:
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0             842     0          2.2         0   1       0           7    0.6
# 1            1021     1          0.5         1   0       1          53    0.7
# 2             563     1          0.5         1   2       1          41    0.9
# 3             615     1          2.5         0   0       0          10    0.8
# 4            1821     1          1.2         0  13       1          44    0.6
# 5            1859     0          0.5         1   3       0          22    0.7
# 6            1821     0          1.7         0   4       1          10    0.8
# 7            1954     0          0.5         1   0       0          24    0.8
# 8            1445     1          0.5         0   0       0          53    0.7
# 9             509     1          0.6         1   2       1           9    0.1
# 10            769     1          2.9         1   0       0           9    0.1
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 200)
print(type(chunks), print(chunks))
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None

# %%
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    # each chunk will work as dataframe
    # the 200 data divide 10 chunk
    print(type(chunk), len(chunk))
# Out:
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200
# <class 'pandas.core.frame.DataFrame'> 200

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    # each chunk will work as dataframe
    # the 200 data divide 10 chunk
    print(type(chunk), len(chunk))
    # if we read chunk data than use chunk.head this will show first 5 values to each chunk
    print(chunk.head())
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
# <class 'pandas.core.frame.DataFrame'> 100
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    # if we read chunk data than use chunk.head this will show first 5 values to each chunk
    print(chunk.head())
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

chunk_list[0]
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#     battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0             842     0          2.2         0   1       0           7    0.6
# 1            1021     1          0.5         1   0       1          53    0.7
# 2             563     1          0.5         1   2       1          41    0.9
# 3             615     1          2.5         0   0       0          10    0.8
# 4            1821     1          1.2         0  13       1          44    0.6
# ..            ...   ...          ...       ...  ..     ...         ...    ...
# 95           1137     1          1.0         0  18       0           7    1.0
# 96           1355     0          2.3         0  10       1          23    0.2
# 97           1665     1          0.5         0   3       1          60    0.2
# 98            657     0          2.5         0   0       0          37    0.7
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

chunk_list[1]
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 100           1883     1          0.5         0   3       1          10
# 101           1732     1          1.1         0   4       1          12
# 102            543     0          0.5         0   0       0          57
# 103           1939     1          2.8         1   0       1          55
# 104            553     0          2.4         1   1       1           8
# ..             ...   ...          ...       ...  ..     ...         ...
# 195           1526     0          2.1         0   1       1          23
# 196           1989     0          2.5         1   0       1          41
# 197           1308     0          1.9         0   0       1          61
# 198            609     0          0.5         0   3       0          26
# 199           1905     0          0.6         1   9       1          36
#
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

chunk_list[15]
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1500           1225     0          0.7         1   6       0          60
# 1501           1970     1          0.5         1   0       1          15
# 1502           1186     1          0.5         1   2       0          21
# 1503           1762     0          0.7         0   7       0          60
# 1504           1731     1          1.4         1   4       1           4
# ...             ...   ...          ...       ...  ..     ...         ...
# 1595           1206     0          3.0         1  10       1          30
# 1596            832     1          0.5         1   1       1           5
# 1597            848     1          2.8         0   1       0           8
# 1598           1851     0          2.9         0   0       0          53
# 1599           1166     1          0.5         0   7       0          59
#
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

chunk_list[19]
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1900           1619     1          1.9         0   2       1          21
# 1901            965     1          1.4         0   1       0          13
# 1902            730     0          1.5         0   9       0           9
# 1903           1361     1          1.4         0   1       0          47
# 1904           1494     0          1.6         0   3       1          45
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 50)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

chunk_list[9]
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 450            712     1          0.5         1   3       1          35
# 451            972     1          1.7         0   0       1          54
# 452           1406     0          0.5         1   2       1          34
# 453           1289     0          0.9         0  10       1          25
# 454            932     0          1.3         0   1       0          64
# 455           1747     1          0.9         0   6       1          48
# 456           1172     1          2.1         1   4       0          41
# 457           1128     1          1.4         0  12       0          53
# 458            664     0          1.2         1   0       0          28
# 459            513     1          0.5         0   6       1          44
# 460           1742     0          2.3         1   9       1          43
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

chunk_list[0].head()
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# ...

# %%
# To read a file in pieces, specify a chunksize as a number or rows:
chunks = pd.read_csv('datasets/train.csv', chunksize = 100)
print(type(chunks), print(chunks))

# we merge whole 20 chunk data using list
# so we create empty list
chunk_list = []
# if we read data TextFileReader in pandas than we use loop
for chunk in chunks:
    chunk_list.append(chunk)

df_0 = chunk_list[0]
df_0.head()
# Out:
# ...
# <class 'pandas.io.parsers.TextFileReader'> None
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# ...
